# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def Sonhizbulma(vi,a,t):
    vf = vi + a*t
    return vf
Sonhizbulma(12,25,36)
# Out:
# 912

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def findperfectnum():
    Perfectnum = []
    sum = 0
    for i in range(1,1000):
        for a in range(1,i):
            if i % a == 0:
                sum += a
        if sum == i:
            Perfectnum.append(i)
        sum = 0
    print(Perfectnum)

findperfectnum()
# Out:
# [6, 28, 496]

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
# 3.Problemin Çözümünü Buraya Yazınız
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8                 pisagorTriangle.append([x, i, int(hyp)])
#       9     return pisagorTriangle
# ---> 11 print(findPisagor())
#
# Cell In[7], line 6, in findPisagor()
#       4 for i in range(1, 100):
#       5     for x in range(1, i + 1):
# ----> 6         hyp = math.sqrt((i ** 2) + (x ** 2))
#       7         if range(100).count(hyp):
#       8             pisagorTriangle.append([x, i, int(hyp)])
#
# NameError: name 'math' is not defined

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
# 4.Problemin Çözümünü Buraya Yazınız
def findPackOfDye(width, height, kaplama):
    box = (width * height) / kaplama
    print(round(box))

findPackOfDye(10, 20, 8)
# Out:
# 25

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
unlu = ["a", "e", "ı", "i", "o", "ö", "u", "ü"]
unsuz = []

def harfsaymaca(word):
    countunlu = 0
    countunsuz = 0
    for letter in word:
        if unlu.count(letter) > 0:
            countunlu += 1
        else:
            countunsuz += 1
    print(f"this word includes {countunlu} vowels and {countunsuz} consonants.")      
harfsaymaca("erendhdh")
# Out:
# this word includes 2 vowels and 6 consonants.

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
def numbers(liste):
    for i in liste:
        if i % 2 == 0:
            print(i)
numbers((15,25,36,35,95,6))
# Out:
# 36
# 6

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
# 7.Problemin Çözümünü Buraya Yazınız
def sumNumbers(i = 0):
    sum = 0
    if i < 10:
        sum = i + sumNumbers(i + 1)
    return sum

print(sumNumbers())
# Out:
# 45
